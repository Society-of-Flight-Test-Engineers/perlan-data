# %%
from getters import get_directories, get_filenames
from capture_filenames import filenames2df
import requests
import bs4
import re
import os
import pandas as pd
# Out:
#   File "<ipython-input-9-f3401c7cefd7>", line 2
#     from capture-filenames import filenames2df
#                 ^
# SyntaxError: invalid syntax

# %%
baseurl = 'http://www.perlanproject.cloud/data/'

urls = get_directories(baseurl)

# %%
urls = get_filenames(urls)

# %%
urls
# Out:
# [{'http://www.perlanproject.cloud/data/': []},
#  {'http://www.perlanproject.cloud/data/Balloon%20Soundings/': ['readme.txt']},
#  {'http://www.perlanproject.cloud/data/Balloon%20Soundings/Graphs/': []},
#  {'http://www.perlanproject.cloud/data/Balloon%20Soundings/Graphs/07_16_2017_Graphs/': []},
#  {'http://www.perlanproject.cloud/data/Balloon%20Soundings/Graphs/07_16_2017_Graphs/07_16_2017_Graphs/': ['07_16_2017_DensityGraph.bmp',
#    '07_16_2017_PathGraph.bmp',
#    '07_16_2017_SkewT-LogP.bmp',
#    '07_16_2017_WDirnGraph.bmp',
#    '07_16_2017_WSpeedGraph.bmp']},
#  {'http://www.perlanproject.cloud/data/Balloon%20Soundings/Graphs/07_18_2017_Graphs/': []},
#  {'http://www.perlanproject.cloud/data/Balloon%20Soundings/Graphs/07_18_2017_Graphs/07_18_2017_Graphs/': ['18_07_2017_DensityGraph.bmp',
#    '18_07_2017_HumGraph.bmp',
#    '18_07_2017_PathGraph.bmp',
#    '18_07_2017_PressGraph.bmp',
#    '18_07_2017_SkewT-LogP.bmp',
#    '18_07_2017_TempGraph.bmp',
# ...

# %%
pd.DataFrame(urls)
# Out:
#     http://www.perlanproject.cloud/data/  \
# 0                                     []
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# ...

# %%
pd.DataFrame(columns=['directory','filename','extension'])
# Out:
# Empty DataFrame
# Columns: [directory, filename, extension]
# Index: []

# %%
filenames2df(urls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cb5e7aa56161> in <module>()
# ----> 1 filenames2df(urls)
#
# NameError: name 'filenames2df' is not defined
